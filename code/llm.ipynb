# %%
import re
import time
import random
random.seed(9898978)
from copy import deepcopy

from pybtex.database import parse_string
import rispy
from rispy.utils import convert_reference_types
from tqdm import tqdm

import openai
openai.api_key = ''
# Out:
# /Users/mikekestemont/miniconda3/envs/py3.11/lib/python3.11/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.2.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
ptype = 'BOOK'
with open(f'../data/ris-dump/2010s/{ptype}.ris', 'r') as bibliography_file:
    entries = convert_reference_types(rispy.load(bibliography_file))
print(len(entries))
entries[:3]
# Out:
# 3891
# [{'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Schlichting, Liesbeth. Mijn eerste Van Dale themaboekjes. Utrecht: Van Dale, 2010. 288 p.',
#   'abstract': 'ISBN: 978-90-6648-640-9 t. e. m. 978-90-6648-645-4. Niet in autopsie.',
#   'date': '22-01-2024',
#   'authors': ['Schlichting, Liesbeth'],
#   'keywords': ['Van Dale Lexicografie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Bogaert, Mark van. Met woorden verleiden: schrijftips voor uw presentaties, mailings & andere wervende teksten. Leuven: Lannoo Campus, 2010. 239 p.',
#   'abstract': 'ISBN: 978-90-209-8952-6. P. 9-8 Eerst dit: haat-liefdeverhouding; p. 233-239 Register.',
#   'date': '22-01-2024',
#   'authors': ['Bogaert, Mark van'],
#   'keywords': ['schrijfadvies',
#    'spreken in het openbaar',
#    'elektronische post',
#    'advertenties'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Lisman, Frans. Antrekoo en kipfilee: peinzingen over optimaal en pessimaal taalgebruik. Velp: Boekhandel Jansen & De Feijter, 2010. 160 p.',
#   'abstract': 'Niet in autopsie. ISBN: 978-90-804188-8-2.',
#   'date': '22-01-2024',
#   'authors': ['Lisman, Frans'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'}]

# %%
random.shuffle(entries)
sample = entries[:50]
sample
# Out:
# [{'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Sterke verhalen: vijf eeuwen vertelcultuur; [concept en samenstelling] Jeroen Salman; met bijdragen van Roeland Harms en Talitha Verheij; [tekstredactie Yvonne Bleyerveld]. Nijmegen: Vantilt, 2014. 160 p.',
#   'abstract': 'ISBN 978-94-6004-168-6. P. 7-8 Voorwoord, door Garrelt Verhoeven en Jeroen Salman; p. 11-21 Ter introductie: het voortleven van verhalen in woord en beeld, door Jeroen Salman; p. 155-157 Literatuur; p. 158 Verantwoording van het beeld- en bronnenmateriaal. Publicatie ter gelegenheid van de tentoonstelling "Sterke verhalen: vijf eeuwen vertelcultuur" bij de Bijzondere Collecties van de Universiteit van Amsterdam, 24 juni t/m 5 oktober 2014. In het voorjaar van 2014 ontving de Universiteit van Amsterdam een belangrijke schenking van een collectie kinderprenten van verzamelaar Nico Boerma. De waardevolle collectie, met tal van uiterst zeldzame prenten, vormt een belangrijke aanvulling op de verzameling populair drukwerk die al bij de UvA aanwezig was. Prenten uit de collectie Boerma zijn van 24 juni tot en met 5 oktober 2014 te zien bij Bijzondere Collecties UvA op de tentoonstelling "Sterke verhalen". Hier is te zien hoe de overlevering van volksverhalen verliep en welke transformaties beroemde verhalen hebben ondergaan. Bij deze tentoonstelling verschijnt het boek "Sterke verhalen: vijf eeuwen vertelcultuur": roekeloze zeelieden die na een schipbreuk op een eiland met dwergen terechtkomen (Gulliver’s Travels), overmoedige wetenschappers die hun ziel aan de duivel verkopen (Faust), deugdzame sloofjes die eindigen als prinses (Assepoester) en hilarische baronnen die op kanonskogels door de lucht vliegen (Baron van Münchhausen). Zij zijn de hoofdpersonen van dit boek. Hun verhalen zijn tijdloos, maar hebben zich wel voortdurend aangepast aan het medium waarin ze werden overgedragen. Wat gebeurde er als een verhaal tot toneelstuk werd bewerkt, van poëzie in proza veranderde of als beeldverhaal in prenten werd uitgebeeld? Hoe en waarom werden sommige verhalen overgenomen door nieuwe media als toverlantaarns, strips, films en tv-series? Centraal in "Sterke verhalen" staat de centsprent, ook wel volksprent of kinderprent genoemd. Deze prenten, die vooral in de achttiende en negentiende eeuw zeer geliefd waren, hebben een cruciale rol gespeeld in de popularisering van \'sterke\' verhalen en in het doorgeven ervan aan latere generaties. Aan het boek en de tentoonstelling ligt ten gondslag het Utrechtse onderzoeksproject "Popularisation and media strategies (1700-1900)", gefinancierd door het NWO-programma Culturele Dynamiek, waarbij het lied en de centsprent in Nederland en België in de achttiende en negentiende eeuw centraal staat. Er is gebruik gemaakt van de prentencollecties van de verzamelaars Nico Boerma, Arie van den Berg (deels geschonken aan Bijzondere Collecties), Aernout Borms, Jo Thijssen, en van instellingen als de Koninklijke Bibliotheek in Den Haag, het Nederlands Openluchtmuseum in Arnhem, het Rijksmuseum in Amsterdam en de afdeling Bijzondere Collecties van de Universiteit van Amsterdam.',
#   'date': '28-03-2017',
#   'authors': ['Salman, Jeroen',
#    'Harms, Roeland',
#    'Verheij, Talitha',
#    'Bleyerveld, Yvonne',
#    'Verhoeven, Garrelt'],
#   'keywords': ['volksverhaal', 'volksverhaalonderzoek'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Desnerck, Roland. Grenzeloos Oostends: Oostends voor gevorderden en voor liefhebbers van een taalkundige trip. Damme: Zorro uitgeverij, 2014. 368 p.',
#   'abstract': 'ISBN 978-94-6168-0310. P. 5-7 Inleiding.',
#   'date': '27-05-2016',
#   'authors': ['Desnerck, Roland'],
#   'keywords': ['dialectwoordenboek', 'Oostende (dialect)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'T\'Sjoen, Yves. "Zoals een grens op de kaart": Nederlandse literatuur in vergelijkend perspectief: gevalstudies. Gent: Academia Press, 2014. 258 p.',
#   'abstract': 'ISBN 978-90-382-2261-5. P. 3-10 Inleiding (p. 9-10 Bibliografie); p. 247-249 Verantwoording; p. 251-258 Register.',
#   'date': '12-11-2014',
#   'authors': ["T'Sjoen, Yves"],
#   'keywords': ['comparatisme', 'receptie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': 'Hooft, P. C. De gedichten; verzorgd en uitgegeven door Johan Koppenol en Ton van Strien; muzikale redactie en toelichting Natascha Veldhorst. Amsterdam: Athenaeum-Polak & Van Gennep, 2012. 869 p.',
#   'abstract': "ISBN 978-90-253-6926-2. Met audio-cd. P. 7-587 Gedichten; p. 589-804 Commentaar; p. 805-822 De dichter Hooft; p. 823-833 'De vloeiendheid zoeken met het oordeel der oren': Hooft en de muziek; p. 834-835 Verantwoording van teksten; p. 836-847 Verantwoording van de melodieën; p. 848-849 Literatuur; p. 851-855 Bijlagen: p. 851-853: 1. Leven en werk van Hooft in jaartallen; p. 853-855 Concordantie op de uitgave Tuynman-Van der Stroom; p. 856-865 Register van beginregels; p. 869 Inhoud van de cd.",
#   'date': '25-06-2012',
#   'authors': ['Koppenol, Johan', 'Strien, Ton van', 'Veldhorst, Natascha'],
#   'keywords': ['Hooft, P. C. (auteur)', 'teksteditie', 'poëzie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Donche, Pieter A. V. P. Driehonderd jaar veilingcatalogi (1717-2017) in de bibliotheek "Stichting de Bethune", Marke. Marke: Pieter Donche, 2017. 269 p.',
#   'abstract': 'P. 5 Woord vooraf; p. 6 Literatuur; p. 21-241 Inventaris veilingcatalogi in de bibliotheekkast; p. 243-253 Inventaris veilingcatalogi in de Algemene Bibliotheek; p. 255-262 Jaarindex; p. 263-267 Naamindex.',
#   'date': '23-02-2023',
#   'authors': ['Donche, Pieter'],
#   'keywords': ['collectie de Bethune', 'veilingcatalogi'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': 'Sijpe, Luk van de. Jan Gerits. Lanaken: K.V.L.S., 2012. 50 p. (Limburgse monografieën; jrg. 23, nr. 4 (okt-dec 2012)).',
#   'abstract': 'P. 34-47 Selectieve bibliografie van Jan Gerits.',
#   'date': '16-01-2014',
#   'authors': ['Sijpe, Luc van de'],
#   'keywords': ['Gerits, Jan (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2019',
#   'title': 'Roemaat, Bianca. Wat maak je me nu?!: inspiratieboek over de menukaart als communicatiemiddel. [Zelhem]: Het Boekenschap, 2019. 159 p.',
#   'abstract': 'ISBN 978-94-92723-37-6. Niet in autopsie.',
#   'date': '19-12-2023',
#   'authors': ['Roemaat, Bianca'],
#   'keywords': ['gastronomische terminologie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2019',
#   'title': 'Simons, Ludo. Niederdeutsches Quartett: Groth, Reuter, Brinckman, Fehrs in Flandern und den Niederlanden. Berlin: Autumnus Verlag, 2019. 144 p.',
#   'abstract': 'ISBN 978-3-96448-007-1. P. 5-10 Proloog, oder: Woans ick tau dat Plattdüütsch kamm; p. 118-137 Anmerkungen; p. 138-139 Quellennachweis.',
#   'date': '05-02-2019',
#   'authors': ['Simons, Ludo'],
#   'keywords': ['literaire betrekkingen met Neder-Duitsland'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2013',
#   'title': 'Boon, Ton den. Verdwijnwoordenboek: duizend en enige woorden die in de vergetelheid zijn geraakt. Varik: Uitgeverij De Weideblik, 2013. 163 p.',
#   'abstract': 'ISBN 978-90-77767-45-0. P. 5-7 Inleiding.',
#   'date': '10-03-2020',
#   'authors': ['Boon, Ton den'],
#   'keywords': ['woordenboek', 'archaïsme'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2015',
#   'title': 'Hendrickx, Marc. Man in de marge: zwartboek letteren. Antwerpen/Rotterdam: De Vries-Brouwers, 2015. 384 p.',
#   'abstract': 'ISBN 978-90-5927-455-6. "\'Man in de marge\' brengt het fascinerende verhaal van 35 jaar leven in de kantlijn van de letteren, met quotes, verwijzingen en informatie van en over meer dan 500 personaliteiten!"',
#   'date': '08-02-2016',
#   'authors': ['Hendrickx, Marc'],
#   'keywords': ['Vlaanderen',
#    'uitgeverijen',
#    'Fonds voor de letteren (Vlaanderen)',
#    'Vlaamse Auteursvereniging',
#    'Stichting Lezen (Vlaanderen)',
#    'subsidiebeleid'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Rutten, Gijsbert, Marijke J. van der Wal. Letters as loot: a sociolinguistic approach to seventeenth- and eighteenth-century Dutch. Amsterdam: John Benjamins Publishing Company, 2014.  XIII, 426 p. (Advances in historical sociolinguistics; 2).',
#   'abstract': 'ISBN 978-90-272-0081-5; ISBN 978-90-272-6957-7 (e-book). P. 409-424 References; p. 425-426 Index.',
#   'date': '13-01-2015',
#   'authors': ['Rutten, Gijsbert', 'Wal, Marijke J. van der'],
#   'keywords': ['historische sociolinguïstiek', 'brieven'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': 'Harmsen van Beek, F. In goed en kwaad: verzameld werk; [redactie: Daan Cartens... et al.; ill. Paul de Lussanet; cartoon Charles Addams]. Amsterdam: De Bezige Bij, 2012. 511 p.',
#   'abstract': 'ISBN 978-90-234-6988-9. 2e dr. 2012; 3e herziene en uitgebreide druk. Amsterdam: De Bezige Bij, 2021. ISBN 978-94-031-1531-3. P. 495-497 Verantwoording; p. 499-508 Bibliografie en oorspronkelijke publicaties; p. 509-512 Biografische aantekening.',
#   'date': '18-06-2012',
#   'authors': ['Cartens, Daan'],
#   'keywords': ['Harmsen van Beek, F. (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2011',
#   'title': 'Commonplace culture in Western Europe in the Early Modern period, III. Legitimation of authority; edited by Joop W. Koopmans and Nils Holger Petersen. Leuven [etc.]: Peeters, 2011. xvi, 205 p. (Groningen studies in cultural change; vol. 40).',
#   'abstract': 'ISBN 978-90-429-2476-5. P. ix-xvi Introduction; p. 185-197 Bibliography; p. 199-205 Index.',
#   'date': '10-03-2011',
#   'authors': ['Koopmans, J. W.', 'Petersen, Nils Holger'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Wolkers, Jan. Dagboek 1975. Amsterdam: De Bezige Bij, 2010. 230 p.',
#   'abstract': 'ISBN 978-90-234-5943-9. P. 223-230 Verklarende namenlijst.',
#   'date': '31-05-2011',
#   'keywords': ['Wolkers, Jan (auteur)', 'dagboek'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2015',
#   'title': 'Purvis, Alston V., René Kok, Gerard Groeneveld. Goed fout: grafische vormgeving in Nederland 1940-1945; redactie: Sytze van der Veen. [Nijmegen]: Uitgeverij Vantilt, 2015. 255 p.',
#   'abstract': 'ISBN 978-94-6004-213-3. P. 10-18 Zwart wit, door Cees W. de Jong; inleiding; p. 252-255 Literatuur.',
#   'date': '28-04-2015',
#   'authors': ['Purvis, Alston W.',
#    'Somers, Erik',
#    'Kok, René',
#    'Groeneveld, Gerard'],
#   'keywords': ['beeldende kunst', 'vormgeven', 'Tweede Wereldoorlog'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2018',
#   'title': 'Gucht, Fieke van der, Marten van der Meulen, Robbe Verlinde [ill.] en Willem van Beylen [ill.]. Het groot Vlaams vloekboek: slimmer schelden en vaardiger vloeken. Tielt: Lannoo, 2018. 143 p.',
#   'abstract': 'ISBN 978-94-014-5342-4. P. 5 [Woord vooraf]; p. 142-143 Bibliografie; p. 143 Index vloek- en scheldwoorden.',
#   'date': '15-07-2019',
#   'authors': ['Gucht, Fieke van der',
#    'Meulen, Marten van der',
#    'Verlinde, Robbe',
#    'Beylen, Willem van'],
#   'keywords': ['vloek', 'scheldwoord'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Arijs, Karen. Vormen van regionaal bewustzijn en nationale identiteit in Belgisch- en Nederlands-Limburg, 1866-1938. Hilversum: Verloren, 2017. 237 p. (Maaslandse Monografieën; 82).',
#   'abstract': 'ISBN 978-90-8704-648-4. Proefschrift Vrije Universiteit Brussel, 2016. P. 232-232 Summary; p. 234-235 Register. Samenvatting van het proefschrift in: Belgisch tijdschrift voor nieuwste geschiedenis (Gent): 46 (2016) 3-4, 260-261.',
#   'date': '19-02-2018',
#   'authors': ['Arijs, Karen'],
#   'keywords': ['Limburg',
#    'thema identiteit',
#    'culturele identiteit',
#    'Limburg cultureel leven in'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2019',
#   'title': 'Japin, Arthur. Geluk, een geheimtaal: dagboeken 2008-2018. Amsterdam; Antwerpen: De Arbeiderspers, 2019. 373 p., [16] p. pl. (Privé-domein; nr. 306).',
#   'abstract': 'ISBN 978-90-295-4050-6. P. 363 Nawoord; p. 365-373 Register.',
#   'date': '23-03-2020',
#   'keywords': ['Japin, Arthur (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'The linguistics enterprise: from knowledge of language to knowledge in linguistics; edited by by Martin Everaert, Tom Lentz, Hannah De Mulder, Øystein Nilse, Arjen Zondervan. Amsterdam; Philadelphia: John Benjamins Publishing Company, 2010. IX, 379 p. (Linguistik aktuell = Linguistics today; vol. 150).',
#   'abstract': 'ISBN 978-90-272-5533-4 geb. ISBN 978-90-272-8866-0 (e-book). P. 377-379; Met literatuuropgaven. Linguistics investigates the systems underlying language, speech, and language use. Linguists seek to develop an understanding of the rules and laws that govern the structure and use of particular languages and the manner in which these interact with internal systems and processes (interpretation, speech perception, and production) and with the outside world (acquisition, use, change and role in society). The articles in this volume present a valuable addition to answering three important questions about knowledge in linguistics: What is knowledge in linguistics, how is it acquired, and how is it put to use? Apart from the data on the specific phenomena addressed in the articles, the book presents insight into the palette of present-day linguistics. In this way, it aims to break open the division of linguistics into subfields thereby making possible cross-fertilisation. [Bron: http://www.benjamins.com]',
#   'date': '20-05-2010',
#   'authors': ['Everaert, Martin',
#    'Lentz, Tom',
#    'Mulder, Hannah de',
#    'Nilsen, Øystein',
#    'Zondervan, Arjen'],
#   'keywords': ['taalkunde',
#    'geschiedenis van de beoefening van de taalwetenschap',
#    'taalverwerving',
#    'taalgebruik',
#    'cognitieve grammatica',
#    'semantiek',
#    'syntaxis'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': 'Sprechen mit Gott: Redeszenen in mittelalterlicher Bibeldichtung und Legende; Nine Miedema, Angela Schrott & Monika Unzeitig (Hg.). Berlin: Akademie Verlag, 2012. VIII, 379 p. (Historische Dialogforschung; 2).',
#   'abstract': 'ISBN 978-3-05-005976-1; e-ISBN 978-3-05-006334-8. P. 1-12 Einleitung, door Nine Miedema, Angela Schrott & Monika Unzeitig; p. 371-379 Personen-, Werk- und Sachregister.',
#   'date': '10-10-2017',
#   'authors': ['Miedema, Nine Robijntje',
#    'Schrott, Angela',
#    'Unzeitig, Monika'],
#   'keywords': ['middeleeuwen',
#    'dialoog',
#    'dialoogbeschrijving',
#    'vergelijkende literatuurgeschiedenis',
#    'bijbelvertaling',
#    'thema religie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Corbeil, Jean-Claude, Ariane Archambault. Van Dale beeldwoordenboek Nederlands-Turks; vertaling Femke van Doorn, Mariska Albers. Utrecht; Antwerpen: Van Dale, 2010. 598 p.',
#   'abstract': 'ISBN 978-90-6648-842-7.',
#   'date': '07-04-2011',
#   'authors': ['Corbeil, Jean-Claude', 'Archambault, Ariane'],
#   'keywords': ['Turks-Nederlands', 'beeldwoordenboeken'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2018',
#   'title': 'Couperus, Louis. Het snoer der ontferming; geillustreerde uitgave met toelichting en de door de auteur gebruikte bronnen, bezorgd door H. T. M. van Vliet. Amsterdam: Van Oorschot, 2018. 414 p.',
#   'abstract': 'ISBN 978-90-282-8226-1. P. 7-63 Inleiding; p. 393-400 Verantwoording; p. 402-407 Lijst van illustraties; p. 410-414 Bibliografie.',
#   'date': '14-07-2020',
#   'authors': ['Vliet, H. T. M. van'],
#   'keywords': ['Couperus, Louis (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': "Bunge, Wiep van. Spinoza past and present: essays on Spinoza, Spinozism, and Spinoza scholarship. Leiden [etc.]: Brill, 2012. XIV, 256 p. (Brill's studies in intellectual history; 215).",
#   'abstract': 'ISBN 978-90-04-23137-5; 978-90-04-23352-2 (e-book).',
#   'date': '27-08-2012',
#   'authors': ['Bunge, Wiep van'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Tettelin, Bart. Anton Vlaskop: documentografie van een literair talent. Lokeren: Bart Tettelin, 2017. 215 p.',
#   'abstract': 'P. 4-5 Voorwoord: Anton Vlaskop, tien jaar later, door Alain Debbaut; p. 213 Nawoord.',
#   'date': '17-01-2023',
#   'authors': ['Tettelin, Bart', 'Debbaut, Alain'],
#   'keywords': ['Vlaskop, Anton (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Claes, Ernest. Aus dem Kriege: Namur 1914; [deutsche Übersetzung aus dem Niederländischen von Johannes Herzog]. Heiligenstadt: F. W. Cordier, 2014. 176 p.',
#   'abstract': 'ISBN 978-3-939848-40-0. P. 6-7 Grußwort, door Jan van Hemelryck; p. 8-9 Von Bücherschränken und einem Reservistenkrug: wie es zu dieser Übersetzung gekommen ist; p. 11-30 Der kleine Krieg des Ernest Claes, door Rudolf van de Perre; [deutsche Übersetzung aus dem Niederländischen von Johannes Herzog] (eerder in het Nederlands verschenen in: Claes, Ernest. Uit den oorlog: Namen 1914; [tek. Coen De Frenne]. Tielt: Lannoo, 1989, p. 9-27, o.d.t. De kleine oorlog van Ernest Claes (Jaarboek van het Ernest Claesgenootschap)).',
#   'date': '24-01-2017',
#   'authors': ['Herzog, Johannes',
#    'Hemelryck, Jan van',
#    'Perre, Rudolf van de'],
#   'keywords': ['Claes, Ernest (auteur)', 'vertalingen in het Duits'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2018',
#   'title': 'Perkament in stukken: teruggevonden middeleeuwse handschriftfragmenten; onder redactie van Bart Jaski, Marco Mostert en Kaj van Vliet. Hilversum: Verloren, 2018. 280 p.',
#   'abstract': 'ISBN: 978-90-8704-742-9. P. 8-9 Woord vooraf; p. 10-45 Ter inleiding; p. 269-273 Noten; p. 274-277 Over de auteurs; p. 278-280 Lijst van signaturen.',
#   'date': '20-02-2024',
#   'authors': ['Jaski, Bart', 'Mostert, Marco', 'Vliet, Kaj van'],
#   'keywords': ['perkament',
#    'tekstoverlevering',
#    'handschriftfragment',
#    'boekgeschiedenis'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2016',
#   'title': 'Waegemans, Emmanuel. Bibliografie van Russische literatuur in Nederlandse vertaling 1985-2015 = Bibliografija russkoj literatury v niderlandskom perevode 1985-2015. Antwerpen: Benerus, 2016. 493 p.',
#   'abstract': 'ISBN\t978-90-816738-5-3 (pbk). Vervolg op: Waegemans, Emmanuel, Cees Willemsen. Bibliografie van Russische literatuur in Nederlandse vertaling 1789-1985 = Bibliografija russkoj literatury v niderlandskom perevode 1789-1985. Leuven: Universitaire Pers, 1991. 391 p. (Symbolae Facultatis Litterarum et Philosophiae Lovaniensis. Series B; vol. 9). ISBN 90-6186-428-3. P. 5-7 Ten geleide; p. 9  Lijst van veel voorkomende vertalers; p. 387-485 Index Russische titels; p. 487-493 Index van vertalers, bewerkers en redacteuren.',
#   'date': '13-02-2017',
#   'authors': ['Waegemans, Emmanuel'],
#   'keywords': ['bibliografieën van vertalingen',
#    'vertalingen uit het Russisch'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Claus, Hugo. De Metsiers. 31e dr. Amsterdam: De Bezige Bij, 2014. 150 p. (Uitgeverij De Bezige Bij 70 jaar).',
#   'abstract': 'ISBN 978-90-234-9242-9. P. 147-150 Dieren aan zelfgekozen kettingen, door Erwin Mortier.',
#   'date': '21-02-2022',
#   'authors': ['Mortier, Erwin'],
#   'keywords': ['Claus, Hugo (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Keesman, Wilma. De eindeloze stad: Troje en Trojaanse oorsprongsmythen in de (laat)middeleeuwse en vroegmoderne Nederlanden. Hilversum: Verloren, 2017. 751 p. (Middeleeuwse studies en bronnen; CLIX).',
#   'abstract': 'ISBN 978-90-8704-553-1. P. 13-21 Inleiding; p. 646-658 Bijlage: mythische stambomen; p. 659-706 Bibliografie; p. 707-715 Samenvatting; p. 716-724 Summary.',
#   'date': '19-03-2018',
#   'authors': ['Keesman, Wilma'],
#   'keywords': ['thema Troje',
#    'ontstaansgeschiedenis',
#    'middeleeuwen',
#    'Segher Diengotgaf (auteur)',
#    'Boendale, Jan van (auteur)',
#    'Brabant cultureel leven in',
#    'thema Brabo',
#    'Hennen van Merchtenen (auteur)',
#    'Roman van Caesar',
#    'Brabants kroniekje',
#    'Die Alderexcellenste Cronyke van Brabant',
#    'hofcultuur',
#    'Dits die excellente cronike van Vlaenderen',
#    'Vaernewijck, Marcus van (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': "Jordens, Peter. Taalverwerving: 'Creating language anew'. Amstelveen: EON Pers, 2010. 43 p.",
#   'abstract': 'ISBN 978-90-77246-38-2. Rede, uitgesproken op 16 oktober 2009 bij het afscheid als hoogleraar toegepaste taalwetenschap aan de Faculteit der Letteren van de Vrije Universiteit te Amsterdam. P. 7-8 Inleiding; p. 41-43 Literatuur.',
#   'date': '11-04-2011',
#   'authors': ['Jordens, Peter'],
#   'keywords': ['taalverwerving'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2013',
#   'title': 'Vielfalt, Variation und Stellung der deutschen Sprache; Karina Schneider-Wiejowski, Birte Kellermeier-Rehbein en Jakob Haselhuber (Hrsg.). Berlijn: De Gruyter, 2013. 578 p.',
#   'abstract': 'ISBN: 978-3-11-030930-0. P. V-VI Vorwort.',
#   'date': '28-11-2023',
#   'authors': ['Schneider, Karin',
#    'Kellermeier-Rehbein, Birte',
#    'Haselhuber, Jakob'],
#   'keywords': ['taalvariatie',
#    'minderheidstaal',
#    'sociolinguïstiek',
#    'taalpolitiek'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Arends, Jan. Lunchpauzegedichten; met een nawoord van Menno Wigman. Tiende druk. Amsterdam/Antwerpen: De Bezige Bij/Lebowski, 2014. 62 p.',
#   'abstract': 'ISBN 978-90-234-8498-1. 1e druk Amsterdam: De Bezige Bij (BB poëzie); 11e druk Amsterdam/Antwerpen: De Bezige Bij/Lebowski, 2015. P. 59-62 Gedichten als dunne bomen.',
#   'date': '12-05-2016',
#   'authors': ['Wigman, Menno'],
#   'keywords': ['Arends, Jan (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2012',
#   'title': 'Rethinking cultural transfer and transmission: reflections and new perspectives; ed. by Petra Broomans and Sandra van Voorst; assistant ed. Karina Smits. Groningen: Barkhuis, 2012. 168 p. (Studies on cultural transfer and transmission; 4).',
#   'abstract': 'ISBN 978-949-148-119-7. P. 9-13 Introduction; p. 149-163 Bibliography; p. 165-168 Index.',
#   'date': '05-03-2013',
#   'authors': ['Broomans, Petra', 'Voorst, Sandra van'],
#   'keywords': ['cultuuroverdracht'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Teirlinck, Herman. Bij mijn venster: mijmeringen in de oude trant. Beersel: Het huis van Herman Teirlinck, 2017. 23 p. [(Uitgaven van Het huis van Herman Teirlinck; 1]).',
#   'abstract': 'ISBN 978-90-9030-740-4. Eerder verschenen in: Teirlinck, Herman. Ode aan mijn hand: tijdgeestige oefeningen. Brussel; Den Haag: Manteau, 1963 (Grote Marnix-pocket; no. 4). P. 18-21 Een nieuw leven voor het huis van Herman Teirlinck, door Sigrid Bousset en Hugo de Greef.',
#   'date': '07-01-2019',
#   'authors': ['Bousset, Sigrid', 'Greef, Hugo de'],
#   'keywords': ['Teirlinck, Herman (auteur)', 'Herman Teirlinck-huis'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2015',
#   'title': 'In het water gevonden: het Amersfoortse Mirakelboek naar het handschrift Brussel, Koninklijke Bibliotheek Albert I, 8179-8180; uitgegeven en hertaald door Dick E. H. de Boer & Ludo Jongen, met medewerking van Juliette Duisterwinkel. Hilversum: Verloren, 2015. 358 p. (Middeleeuwse studies en bronnen; 155)',
#   'abstract': 'ISBN 978-90-8704-505-0. P. 11-34 Inleiding; p. 35-281 Tekst & hertaling; p. 283-284 Appendix 1: verantwoording van de kritische tekst en de hertaling; p. 285-291 Appendix 2: Beschrijving Dossier Rosweyde (Brussel, Koninklijke Bibliotheek Albert I, 8179-8180); p. 292-331 Appendix 3: Dossier Rosweyde (tekst) [Aantekeningen en vertalingen van Heribert Rosweyde]; Dossier Rosweyde (vertaling) [Aantekeningen en vertalingen van Heribert Rosweyde; p. 332-337 Appendix 4: aantekeningen op de eerste en laatste bladen in een Amersfoorts manuscript (tekst); Aantekeningen op de eerste en laatste bladen in een Amersfoorts manuscript (vertaling); p. 338-342 Appendix 5: concordantie; p. 343-350 Bibliografie; p. 351-356 Register van topografische namen; p. 357-358 Register van kwalen; p. 358 Register van maten en gewichten.',
#   'date': '12-09-2016',
#   'authors': ['Boer, D. E. H. de', 'Jongen, Ludo', 'Duisterwinkel, Juliette'],
#   'keywords': ['Amersfoort',
#    "Mirakelboeck van Onser Liever Vrouwen t'Amersfoert",
#    'mirakelboek'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2015',
#   'title': 'Pols, Gijsbert. Naturalistische Moderne - Arno Holz und Lodewijk van Deyssel. Münster: Nodus Publikationen, 2015. 226 p.',
#   'abstract': 'ISBN 978-3-89323-019-8. P. 11-19 Einleitung; p. 213-226 Bibliographie (p. 214 Lodewijk van Deyssel; p. 214-215 Arno Holz; p. 215-216 Sonstige Primärliteratur; p. 216 Veröffentliche Korrespondenzen; p. 216-226 Sekundärliteratur).',
#   'date': '19-01-2017',
#   'authors': ['Pols, Gijsbert'],
#   'keywords': ['naturalisme',
#    'modernisme',
#    'Deyssel, Lodewijk van (auteur)',
#    'Holz, Arno'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2018',
#   'title': 'Woekering en weigering: metamorfosen en identiteit in het werk van Jacq Vogelaar; onder redactie van Hans Demeyer & Sven Vitse. Gent: Academia Press, 2018. 262 p. (SEL-reeks; 11).',
#   'abstract': 'ISBN 978-94-0145-263-2. P. 3-13 Jacq Vogelaar: schrijven als taalarbeid?, door Hans Demeyer en Sven Vitse; p. 257-262 Index.',
#   'date': '04-04-2019',
#   'authors': ['Demeyer, Hans', 'Vitse, Sven'],
#   'keywords': ['Vogelaar, Jacq Firmin (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2015',
#   'title': 'Bilderdijk, Willem. Vale!: afscheidsgedichten van Willem Bilderdijk; uitgegeven, ingeleid en toegelicht door Marinus van Hattum. Amstelveen: EON Pers, 2016. 58 p.',
#   'abstract': 'Niet in autopsie. ISBN:  978-90-77246-76-4.',
#   'date': '09-01-2024',
#   'authors': ['Hattum, Marinus van'],
#   'keywords': ['afscheidspoëzie', 'Bilderdijk, Willem (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2014',
#   'title': 'Gerbrandy, Piet. De jacht op het sublieme: zin, lust en poëzie. Amsterdam: De Bezige Bij, 2014. 346 p.',
#   'abstract': 'ISBN 978-90-234-8807-1. P. 323-332 Literatuur; p. 333-335 Verantwoording; p. 337-346 Register met namen.',
#   'date': '18-11-2014',
#   'keywords': ['cultuurfilosofie', 'essay', 'Gerbrandy, Piet (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2016',
#   'title': 'Vanderputten, Steven, Jelle Haemers en Tim Soens. Typologie en heuristiek van de bronnen voor de geschiedenis van de middeleeuwen. Gent: Academia Press, 2016. 188 p.',
#   'abstract': 'ISBN: 978-90-382-2617-0. P. 9 Woord vooraf; p. 11-15 Begripsomschrijving en toelichting.',
#   'date': '14-12-2023',
#   'authors': ['Vanderputten, Steven', 'Haemers, Jelle', 'Soens, Tim'],
#   'keywords': ['typologie',
#    'heuristiek',
#    'tekstoverlevering',
#    'middeleeuwen',
#    'bronnenonderzoek',
#    'naslagwerk'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2018',
#   'title': 'Meulen, Dik van der. Jac. P. Thijsse: natuurbeschermer en schrijver. Zeist/Amsterdam: KNNV/Heimans & Thijsse Stichting, 2018. 95 p.',
#   'abstract': 'ISBN 978-90-5011-6565. P. 87-92 Noten ; p. 93 Verantwoording en dankwoord; p. 94-95 Register.',
#   'date': '29-04-2019',
#   'authors': ['Meulen, Dik van der'],
#   'keywords': ['Thijsse, Jac. P. (auteur)', 'natuurbescherming'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Taalkunde en het schoolvak Nederlands; [onder redactie van Hans Hulshof, Ton Hendrix; eindredactie: Johan Graus; fotografie: Anda van Riet]. Amsterdam: VLLT, 2010. 65 p.',
#   'abstract': 'Op omslag: Levende Talen. Uitgave van de sectie Nederlands van de Vereniging van Leraren in Levende Talen en Levende talen magazine. P. 5-11 Ten geleide: Het schoolvak Nederlands inhoudelijk aanvullen, door Ton Hendrix & Hans Hulshof.',
#   'date': '11-08-2010',
#   'authors': ['Hulshof, Hans', 'Hendrix, Ton', 'Graus, Johan'],
#   'keywords': ['taalbeheersing', 'voortgezet onderwijs', 'taalkunde'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2019',
#   'title': 'Kijk op een rijk verleden: 50 jaar Heemkring De Souvereinen Lokeren; redactie: André de Munck; hoofdredacteur: Peter van Wichelen. Lokeren: De Souvereinen; Lokeren: Stad Lokeren, 2019. 326 p.',
#   'abstract': 'P. 7 Voorwoord, door Marina van Hoorick.',
#   'date': '28-02-2023',
#   'authors': ['Munck, André de', 'Wichelen, Peter van'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2013',
#   'title': 'Bras, Kick. Een met de Ene: protestantse mystiek van Abraham Kuyper tot Maria de Groot. Vught: Skandalon, 2013. 320 p.',
#   'abstract': 'ISBN 978-94-90708-78-8. P. 9-16 Inleiding; met literatuuropgave.',
#   'date': '16-10-2013',
#   'authors': ['Bras, K. E.'],
#   'keywords': ['protestantisme',
#    'mystiek',
#    'twintigste-eeuwse letterkunde',
#    'Kuyper, Abraham (auteur)',
#    'Mérode, Willem de (auteur)',
#    'Vorster, D. A. (auteur)',
#    'Roland Holst-van der Schalk, Henriëtte (auteur)',
#    'Miskotte, K. H. (auteur)',
#    'Jelsma, Auke (auteur)',
#    'Groot, Maria de (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Identiteitspolitiek: media en de constructie van gemeenschapsgevoel; onder redactie van Marcel Broersma en Joop W. Koopmans. Hilversum: Verloren, 2010. 186 p.',
#   'abstract': 'ISBN 978-90-8704-119-9. P. 9-18 Media en identiteitspolitiek; ter inleiding, door Marcel Broersma.',
#   'date': '20-04-2011',
#   'authors': ['Broersma, Marcel', 'Koopmans, J. W.'],
#   'keywords': ['nationale identiteit', 'media', 'identiteitsdenken'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Namenwirth, Micha. Verzameld proza, I. Nico; Absoluut gehoor. Brussel: VUBPRESS, 2010. 570 p.',
#   'abstract': 'ISBN 987-90-5487-712-7. P. 9-50 Inleidende teksten.',
#   'date': '29-04-2014',
#   'keywords': ['Namenwirth, Micha (auteur)'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Reinders, Michel. Gedrukte chaos: populisme en moord in het rampjaar 1672. Amsterdam: Balans, 2010. 333 p.',
#   'abstract': 'ISBN 978-94-600-3284-4. Vertaling en bewerking van: Printed pandemonium: the power of the public and the market for popular political publications in the early modern Dutch Republic. Oorspronkelijk verschenen als proefschrift Erasmus Universiteit Rotterdam, 2008. P. 9-23 Inleiding; p. 280-323 Noten; p. 326-333 Personenregister.',
#   'date': '19-01-2011',
#   'authors': ['Reinders, Michel'],
#   'keywords': ['thema rampjaar 1672', 'pamflet', 'politieke geschiedenis'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2013',
#   'title': 'Meerkerk, Edwin van. De gebroeders Van Hogendorp: botsende idealen in de kraamkamer van het Koninkrijk. Amsterdam/Antwerpen: Atlas Contact, 2013. 316 p.',
#   'abstract': 'ISBN 978-90-450-1933-8. P. 270-286 Literatuur en bronnen; p. 289-310 Noten; p. 311-316 Register.',
#   'date': '16-10-2013',
#   'authors': ['Meerkerk, Edwin van'],
#   'keywords': ['Hogendorp, Dirk van (auteur)', 'biografie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2017',
#   'title': 'Herreweghe, Jan van. Dode letters: over de oneindige bibliotheek, alleslezers, niet-lezers, ongelezen boeken, onleesbare boeken, net niet verschenen boeken, ongeschreven boeken en onuitgegeven manuscripten. Harelbeke: De Gebeten Hond, 2017. 150 p. (Het menselijk tekort bij een teveel aan papier; 9).',
#   'abstract': 'ISBN 978-94-92776-00-6. Vierendertigste brief omtrent de bibliofilie. P. 144-149 Bibliografie. Lange brief over verschillende aspecten van de bibliofilie die in de periode 2010-2017 tot stand kwam en op 15 april 2017 werd verstuurd naar André Vandermoere te Gent.',
#   'date': '16-01-2019',
#   'authors': ['Herreweghe, Jan van'],
#   'keywords': ['bibliofilie'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'},
#  {'type_of_reference': 'Whole book',
#   'year': '2010',
#   'title': 'Genootschap Onze Taal. Grammatica geregeld; [redactie: Taalwerkplaats]. Den Haag: Sdu Uitgevers, 2010. 123 p. (Taal geregeld).',
#   'abstract': 'ISBN 978-90-12-58134-9. P. 6 7 Inleiding; p. 121-123 Register.',
#   'date': '26-01-2011',
#   'authors': ['Genootschap Onze Taal'],
#   'keywords': ['grammatica'],
#   'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)'}]

# %%
desc_strs = [' '.join(entry['title'].split()) for entry in sample]
desc_strs[:5]
# Out:
# ['Sterke verhalen: vijf eeuwen vertelcultuur; [concept en samenstelling] Jeroen Salman; met bijdragen van Roeland Harms en Talitha Verheij; [tekstredactie Yvonne Bleyerveld]. Nijmegen: Vantilt, 2014. 160 p.',
#  'Desnerck, Roland. Grenzeloos Oostends: Oostends voor gevorderden en voor liefhebbers van een taalkundige trip. Damme: Zorro uitgeverij, 2014. 368 p.',
#  'T\'Sjoen, Yves. "Zoals een grens op de kaart": Nederlandse literatuur in vergelijkend perspectief: gevalstudies. Gent: Academia Press, 2014. 258 p.',
#  'Hooft, P. C. De gedichten; verzorgd en uitgegeven door Johan Koppenol en Ton van Strien; muzikale redactie en toelichting Natascha Veldhorst. Amsterdam: Athenaeum-Polak & Van Gennep, 2012. 869 p.',
#  'Donche, Pieter A. V. P. Driehonderd jaar veilingcatalogi (1717-2017) in de bibliotheek "Stichting de Bethune", Marke. Marke: Pieter Donche, 2017. 269 p.']

# %%
batch_size = 5
str_batches = [desc_strs[i:i + batch_size] for i in range(0, len(desc_strs), batch_size)]
ris_batches = [entries[i:i + batch_size] for i in range(0, len(desc_strs), batch_size)]
print('#', len(str_batches))
print('#', len(ris_batches))
# Out:
# # 10
# # 10

# %%
bibtexs = []

promts = {
            'JOUR': 'Can you parse the following, Dutch-language bibliographic \
                            descriptions (each on a separate line) to valid bibtex entries? \
                            The type of publication should be "@article" for all of them.\
                            Just return the bibtex entries please, and nothing else (no explanation). \
                            If you come across a month, please add the month between round brackets to \
                            the number field: e.g. number = {9 (okt)}. Use the keyword `and` to separate \
                            authors, instead of commas. \
                            Make sure that you return the same number of outputs as I provide inputs; \
                            that is very important. Also, make sure that the bibtex-entries which you \
                            return have a unique key.',
            'BOOK': 'Can you parse the following, Dutch-language bibliographic \
                            descriptions (each on a separate line) to valid bibtex entries? \
                            The type of publication should be "@book" for all of them.\
                            Just return the bibtex entries please, and nothing else (no explanation). \
                            Use the keyword `and` to separate authors and editors, instead of commas. \
                            Do not use the bibtex "address" field for the place of publication, e.g. "address = {Amsterdam/Antwerpen}". \
                            Make sure that you return the same number of outputs as I provide inputs; \
                            that is very important. Also, make sure that the bibtex-entries which you \
                            return have a unique key.',
          
        }

def parse_batch(batch, main_prompt):
    messages = [{'role': 'user',
                'content': main_prompt + ' -> ' + '\n'.join(batch)}]
    responses = openai.ChatCompletion.create(model='gpt-3.5-turbo', messages=messages)
    return responses['choices'][0]['message']['content']

# %%
updated_ris = []
update_fields = {'JOUR': ['title', 'volume', 'number', 'year', 'pages'],
                 'BOOK': ['title', 'volume', 'publisher', 'address', 'pages', 'series', 'editora', 'translator']}

def update_ris(ris, bibt, ptype):
    ris['notes_abstract'] = ris['title']
    for k in update_fields[ptype]:
        if k == 'pages' and 'pages' in bibt.fields:
            pages = bibt.fields[k].split('-')
            if len(pages) == 2:
                ris['start_page'] = pages[0]
                ris['end_page'] = pages[1]
        else:
            try:
                ris[k] = bibt.fields[k]
            except KeyError:
                pass
    return ris

for ris_batch, str_batch in tqdm(list(zip(ris_batches, str_batches))):
    time.sleep(1)
    bibtexs = parse_batch(str_batch, main_prompt=promts[ptype])
    bibtexs = parse_string(bibtexs, bib_format="bibtex")

    for ris, bibt in zip(ris_batch, bibtexs.entries):
        print('..........................................')
        bibt = bibtexs.entries[bibt]
        print(bibt)
        updated_ris.append(update_ris(ris, bibt, ptype=ptype))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:08<01:15,  8.41s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Sterke verhalen: vijf eeuwen vertelcultuur'),
#     ('contributor', 'Roeland Harms and Talitha Verheij and Yvonne Bleyerveld'),
#     ('publisher', 'Vantilt'),
#     ('year', '2014'),
#     ('pages', '160')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Salman, Jeroen')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Grenzeloos Oostends: Oostends voor gevorderden en voor liefhebbers van een taalkundige trip'),
#     ('publisher', 'Zorro uitgeverij'),
#     ('year', '2014'),
#     ('pages', '368')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Desnerck, Roland')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', '"Zoals een grens op de kaart": Nederlandse literatuur in vergelijkend perspectief: gevalstudies'),
#     ('publisher', 'Academia Press'),
#     ('year', '2014'),
#     ('pages', '258')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person("T'Sjoen, Yves")])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('contributor', 'Natascha Veldhorst'),
#     ('publisher', 'Athenaeum-Polak \\& Van Gennep'),
#     ('year', '2012'),
#     ('pages', '869')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Hooft, P. C.')]), ('editor', [Person('Koppenol, Johan'), Person('van Strien, Ton')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Driehonderd jaar veilingcatalogi (1717-2017) in de bibliotheek "Stichting de Bethune", Marke'),
#     ('publisher', 'Pieter Donche'),
#     ('year', '2017'),
#     ('pages', '269')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Donche, Pieter A. V. P.')])]))
#  20%|██        | 2/10 [00:15<00:59,  7.41s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Limburgse monografieën; jrg. 23, nr. 4 (okt-dec 2012)'),
#     ('year', '2012'),
#     ('publisher', 'K.V.L.S.'),
#     ('pages', '50')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Sijpe, Luk van de'), Person('Gerits, Jan')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Wat maak je me nu?!: inspiratieboek over de menukaart als communicatiemiddel'),
#     ('year', '2019'),
#     ('publisher', 'Het Boekenschap'),
#     ('pages', '159')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Roemaat, Bianca')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Niederdeutsches Quartett: Groth, Reuter, Brinckman, Fehrs in Flandern und den Niederlanden'),
#     ('year', '2019'),
#     ('publisher', 'Autumnus Verlag'),
#     ('pages', '144')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Simons, Ludo')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Verdwijnwoordenboek: duizend en enige woorden die in de vergetelheid zijn geraakt'),
#     ('year', '2013'),
#     ('publisher', 'Uitgeverij De Weideblik'),
#     ('pages', '163')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Boon, Ton den')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Man in de marge: zwartboek letteren'),
#     ('year', '2015'),
#     ('publisher', 'De Vries-Brouwers'),
#     ('pages', '384')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Hendrickx, Marc')])]))
#  30%|███       | 3/10 [00:28<01:10, 10.00s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Letters as loot: a sociolinguistic approach to seventeenth- and eighteenth-century Dutch'),
#     ('publisher', 'John Benjamins Publishing Company'),
#     ('year', '2014'),
#     ('pages', 'XIII, 426'),
#     ('series', 'Advances in historical sociolinguistics'),
#     ('number', '2')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Rutten, Gijsbert'), Person('van der Wal, Marijke J.')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'In goed en kwaad: verzameld werk'),
#     ('illustrator', 'Paul de Lussanet'),
#     ('publisher', 'De Bezige Bij'),
#     ('year', '2012'),
#     ('pages', '511')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Harmsen van Beek, F.')]), ('editor', [Person('Cartens, Daan'), Person('others')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Commonplace culture in Western Europe in the Early Modern period, III. Legitimation of authority'),
#     ('publisher', 'Peeters'),
#     ('year', '2011'),
#     ('pages', 'xvi, 205'),
#     ('series', 'Groningen studies in cultural change'),
#     ('volume', '40')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Koopmans, Joop W.'), Person('Petersen, Nils Holger')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Dagboek 1975'),
#     ('publisher', 'De Bezige Bij'),
#     ('year', '2010'),
#     ('pages', '230')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Wolkers, Jan')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Goed fout: grafische vormgeving in Nederland 1940-1945'),
#     ('publisher', 'Uitgeverij Vantilt'),
#     ('year', '2015'),
#     ('pages', '255')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Purvis, Alston V.'), Person('Kok, René'), Person('Groeneveld, Gerard')]), ('editor', [Person('van der Veen, Sytze')])]))
#  40%|████      | 4/10 [00:38<01:00, 10.07s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Het groot Vlaams vloekboek: slimmer schelden en vaardiger vloeken'),
#     ('year', '2018'),
#     ('publisher', 'Lannoo'),
#     ('pages', '143')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('van der Gucht, Fieke'), Person('van der Meulen, Marten'), Person('Verlinde, Robbe [ill.]'), Person('van Beylen, Willem [ill.]')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Vormen van regionaal bewustzijn en nationale identiteit in Belgisch- en Nederlands-Limburg, 1866-1938'),
#     ('year', '2017'),
#     ('publisher', 'Verloren'),
#     ('pages', '237'),
#     ('series', 'Maaslandse Monografieën'),
#     ('number', '82')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Arijs, Karen')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Geluk, een geheimtaal: dagboeken 2008-2018'),
#     ('year', '2019'),
#     ('publisher', 'De Arbeiderspers'),
#     ('pages', '373'),
#     ('note', '[16] p. pl.'),
#     ('series', 'Privé-domein'),
#     ('number', '306')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Japin, Arthur')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'The linguistics enterprise: from knowledge of language to knowledge in linguistics'),
#     ('year', '2010'),
#     ('publisher', 'John Benjamins Publishing Company'),
#     ('pages', 'IX, 379'),
#     ('series', 'Linguistik aktuell = Linguistics today'),
#     ('volume', '150')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Everaert, Martin'), Person('Lentz, Tom'), Person('De Mulder, Hannah'), Person('Nilse, Øystein'), Person('Zondervan, Arjen')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Sprechen mit Gott: Redeszenen in mittelalterlicher Bibeldichtung und Legende'),
#     ('year', '2012'),
#     ('publisher', 'Akademie Verlag'),
#     ('pages', 'VIII, 379'),
#     ('series', 'Historische Dialogforschung'),
#     ('number', '2')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Miedema, Nine'), Person('Schrott, Angela'), Person('Unzeitig, Monika')])]))
#  50%|█████     | 5/10 [00:45<00:45,  9.07s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Van Dale beeldwoordenboek Nederlands-Turks'),
#     ('translator', 'van Doorn, Femke and Albers, Mariska'),
#     ('year', '2010'),
#     ('publisher', 'Van Dale'),
#     ('pages', '598')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Corbeil, Jean-Claude'), Person('Archambault, Ariane')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Het snoer der ontferming'),
#     ('year', '2018'),
#     ('publisher', 'Van Oorschot'),
#     ('pages', '414')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Couperus, Louis')]), ('editor', [Person('van Vliet, H. T. M.')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Spinoza past and present: essays on Spinoza, Spinozism, and Spinoza scholarship'),
#     ('year', '2012'),
#     ('publisher', 'Brill'),
#     ('pages', 'XIV, 256'),
#     ('series', "Brill's studies in intellectual history"),
#     ('number', '215')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Bunge, Wiep van')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Anton Vlaskop: documentografie van een literair talent'),
#     ('year', '2017'),
#     ('publisher', 'Bart Tettelin'),
#     ('pages', '215')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Tettelin, Bart')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Aus dem Kriege: Namur 1914'),
#     ('translator', 'Herzog, Johannes'),
#     ('year', '2014'),
#     ('publisher', 'F. W. Cordier'),
#     ('pages', '176')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Claes, Ernest')])]))
#  60%|██████    | 6/10 [00:53<00:34,  8.65s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Perkament in stukken: teruggevonden middeleeuwse handschriftfragmenten'),
#     ('year', '2018'),
#     ('publisher', 'Verloren'),
#     ('pages', '280')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Jaski, Bart'), Person('Mostert, Marco'), Person('van Vliet, Kaj')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Bibliografie van Russische literatuur in Nederlandse vertaling 1985-2015 = Bibliografija russkoj literatury v niderlandskom perevode 1985-2015'),
#     ('year', '2016'),
#     ('publisher', 'Benerus'),
#     ('pages', '493')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Waegemans, Emmanuel')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'De Metsiers'),
#     ('edition', '31'),
#     ('year', '2014'),
#     ('publisher', 'De Bezige Bij'),
#     ('pages', '150'),
#     ('note', 'Uitgeverij De Bezige Bij 70 jaar')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Claus, Hugo')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'De eindeloze stad: Troje en Trojaanse oorsprongsmythen in de (laat)middeleeuwse en vroegmoderne Nederlanden'),
#     ('year', '2017'),
#     ('publisher', 'Verloren'),
#     ('series', 'Middeleeuwse studies en bronnen'),
#     ('number', 'CLIX'),
#     ('pages', '751')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Keesman, Wilma')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', "Taalverwerving: 'Creating language anew'"),
#     ('year', '2010'),
#     ('publisher', 'EON Pers'),
#     ('address', 'Amstelveen'),
#     ('pages', '43')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Jordens, Peter')])]))
#  70%|███████   | 7/10 [01:03<00:27,  9.14s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Vielfalt, Variation und Stellung der deutschen Sprache'),
#     ('year', '2013'),
#     ('publisher', 'De Gruyter'),
#     ('pages', '578')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Schneider-Wiejowski, Karina'), Person('Kellermeier-Rehbein, Birte'), Person('Haselhuber, Jakob')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Lunchpauzegedichten'),
#     ('year', '2014'),
#     ('publisher', 'De Bezige Bij/Lebowski'),
#     ('address', 'Amsterdam/Antwerpen'),
#     ('pages', '62')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Arends, Jan')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Rethinking cultural transfer and transmission: reflections and new perspectives'),
#     ('assistant_editor', 'Karina Smits'),
#     ('year', '2012'),
#     ('publisher', 'Barkhuis'),
#     ('address', 'Groningen'),
#     ('series', 'Studies on cultural transfer and transmission'),
#     ('volume', '4'),
#     ('pages', '168')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Broomans, Petra'), Person('van Voorst, Sandra')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Bij mijn venster: mijmeringen in de oude trant'),
#     ('year', '2017'),
#     ('publisher', 'Het huis van Herman Teirlinck'),
#     ('address', 'Beersel'),
#     ('pages', '23'),
#     ('series', 'Uitgaven van Het huis van Herman Teirlinck'),
#     ('volume', '1')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Teirlinck, Herman')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'In het water gevonden: het Amersfoortse Mirakelboek naar het handschrift Brussel, Koninklijke Bibliotheek Albert I, 8179-8180'),
#     ('collaborator', 'Juliette Duisterwinkel'),
#     ('year', '2015'),
#     ('publisher', 'Verloren'),
#     ('address', 'Hilversum'),
#     ('series', 'Middeleeuwse studies en bronnen'),
#     ('volume', '155'),
#     ('pages', '358')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('de Boer, Dick E. H.'), Person('Jongen, Ludo')])]))
#  80%|████████  | 8/10 [01:11<00:17,  8.79s/it]
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Naturalistische Moderne - Arno Holz und Lodewijk van Deyssel'),
#     ('year', '2015'),
#     ('publisher', 'Nodus Publikationen')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Pols, Gijsbert')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Woekering en weigering: metamorfosen en identiteit in het werk van Jacq Vogelaar'),
#     ('year', '2018'),
#     ('publisher', 'Academia Press'),
#     ('series', 'SEL-reeks; 11')],
#   persons=OrderedCaseInsensitiveDict([('editor', [Person('Demeyer, Hans'), Person('Vitse, Sven')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Vale!: afscheidsgedichten van Willem Bilderdijk'),
#     ('year', '2016'),
#     ('publisher', 'EON Pers')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Bilderdijk, Willem')]), ('editor', [Person('van Hattum, Marinus')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'De jacht op het sublieme: zin, lust en poëzie'),
#     ('year', '2014'),
#     ('publisher', 'De Bezige Bij')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Gerbrandy, Piet')])]))
# ..........................................
# Entry('book',
#   fields=[
#     ('title', 'Typologie en heuristiek van de bronnen voor de geschiedenis van de middeleeuwen'),
#     ('year', '2016'),
#     ('publisher', 'Academia Press')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Vanderputten, Steven'), Person('Haemers, Jelle'), Person('Soens, Tim')])]))
#  80%|████████  | 8/10 [01:22<00:20, 10.28s/it]
# ---------------------------------------------------------------------------
# DuplicateField                            Traceback (most recent call last)
# Cell In[7], line 23
#      21 time.sleep(1)
#      22 bibtexs = parse_batch(str_batch, main_prompt=promts[ptype])
# ---> 23 bibtexs = parse_string(bibtexs, bib_format="bibtex")
#      25 for ris, bibt in zip(ris_batch, bibtexs.entries):
#      26     print('..........................................')
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/pybtex/database/__init__.py:942, in parse_string(value, bib_format, **kwargs)
#     932 """
#     933 Parse a Unicode string containing bibliography data and return a :py:class:`.BibliographyData` object.
#     934
#    (...)
#     938 .. versionadded:: 0.19
#     939 """
#     941 parser = find_plugin('pybtex.database.input', bib_format)(**kwargs)
# --> 942 return parser.parse_string(value)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/pybtex/database/input/bibtex.py:407, in Parser.parse_string(self, text)
#     405         self.process_preamble(*entry[1])
#     406     else:
# --> 407         self.process_entry(entry_type, *entry[1])
#     408 return self.data
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/pybtex/database/input/bibtex.py:364, in Parser.process_entry(self, entry_type, key, fields)
#     362 for field_name, field_value_list in fields:
#     363     if field_name.lower() in seen_fields:
# --> 364         self.handle_error(DuplicateField(key, field_name))
#     365         continue
#     367     field_value = textutils.normalize_whitespace(self.flatten_value_list(field_value_list))
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/pybtex/database/input/bibtex.py:385, in Parser.handle_error(self, error)
#     383 def handle_error(self, error):
#     384     from pybtex.errors import report_error
# --> 385     report_error(error)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/pybtex/errors.py:78, in report_error(exception)
#      75     return
#      77 if strict:
# ---> 78     raise exception
#      79 else:
#      80     print_error(exception, 'WARNING: ')
#
# DuplicateField: entry with key kijk2019 has a duplicate editor field

# %%
updated_ris[0]
# Out:
# {'type_of_reference': 'Whole book',
#  'year': '2014',
#  'title': 'Sterke verhalen: vijf eeuwen vertelcultuur',
#  'abstract': 'ISBN 978-94-6004-168-6. P. 7-8 Voorwoord, door Garrelt Verhoeven en Jeroen Salman; p. 11-21 Ter introductie: het voortleven van verhalen in woord en beeld, door Jeroen Salman; p. 155-157 Literatuur; p. 158 Verantwoording van het beeld- en bronnenmateriaal. Publicatie ter gelegenheid van de tentoonstelling "Sterke verhalen: vijf eeuwen vertelcultuur" bij de Bijzondere Collecties van de Universiteit van Amsterdam, 24 juni t/m 5 oktober 2014. In het voorjaar van 2014 ontving de Universiteit van Amsterdam een belangrijke schenking van een collectie kinderprenten van verzamelaar Nico Boerma. De waardevolle collectie, met tal van uiterst zeldzame prenten, vormt een belangrijke aanvulling op de verzameling populair drukwerk die al bij de UvA aanwezig was. Prenten uit de collectie Boerma zijn van 24 juni tot en met 5 oktober 2014 te zien bij Bijzondere Collecties UvA op de tentoonstelling "Sterke verhalen". Hier is te zien hoe de overlevering van volksverhalen verliep en welke transformaties beroemde verhalen hebben ondergaan. Bij deze tentoonstelling verschijnt het boek "Sterke verhalen: vijf eeuwen vertelcultuur": roekeloze zeelieden die na een schipbreuk op een eiland met dwergen terechtkomen (Gulliver’s Travels), overmoedige wetenschappers die hun ziel aan de duivel verkopen (Faust), deugdzame sloofjes die eindigen als prinses (Assepoester) en hilarische baronnen die op kanonskogels door de lucht vliegen (Baron van Münchhausen). Zij zijn de hoofdpersonen van dit boek. Hun verhalen zijn tijdloos, maar hebben zich wel voortdurend aangepast aan het medium waarin ze werden overgedragen. Wat gebeurde er als een verhaal tot toneelstuk werd bewerkt, van poëzie in proza veranderde of als beeldverhaal in prenten werd uitgebeeld? Hoe en waarom werden sommige verhalen overgenomen door nieuwe media als toverlantaarns, strips, films en tv-series? Centraal in "Sterke verhalen" staat de centsprent, ook wel volksprent of kinderprent genoemd. Deze prenten, die vooral in de achttiende en negentiende eeuw zeer geliefd waren, hebben een cruciale rol gespeeld in de popularisering van \'sterke\' verhalen en in het doorgeven ervan aan latere generaties. Aan het boek en de tentoonstelling ligt ten gondslag het Utrechtse onderzoeksproject "Popularisation and media strategies (1700-1900)", gefinancierd door het NWO-programma Culturele Dynamiek, waarbij het lied en de centsprent in Nederland en België in de achttiende en negentiende eeuw centraal staat. Er is gebruik gemaakt van de prentencollecties van de verzamelaars Nico Boerma, Arie van den Berg (deels geschonken aan Bijzondere Collecties), Aernout Borms, Jo Thijssen, en van instellingen als de Koninklijke Bibliotheek in Den Haag, het Nederlands Openluchtmuseum in Arnhem, het Rijksmuseum in Amsterdam en de afdeling Bijzondere Collecties van de Universiteit van Amsterdam.',
#  'date': '28-03-2017',
#  'authors': ['Salman, Jeroen',
#   'Harms, Roeland',
#   'Verheij, Talitha',
#   'Bleyerveld, Yvonne',
#   'Verhoeven, Garrelt'],
#  'keywords': ['volksverhaal', 'volksverhaalonderzoek'],
#  'name_of_database': 'Bibliografie van de Nederlandse Taal- en Literatuurwetenschap (BNTL)',
#  'notes_abstract': 'Sterke verhalen: vijf eeuwen vertelcultuur',
#  'publisher': 'Vantilt',
#  'address': 'Nijmegen'}

# %%
ris_mapping = deepcopy(rispy.TAG_KEY_MAPPING)
ris_mapping['CY'] = 'address'
ris_mapping['T2'] = 'series'

with open(f'llm_test-{ptype}.ris', 'w') as bibliography_file:
    rispy.dump(updated_ris, bibliography_file, mapping=ris_mapping)

# %%
ris_mapping
# Out:
# {'TY': 'type_of_reference',
#  'A1': 'first_authors',
#  'A2': 'secondary_authors',
#  'A3': 'tertiary_authors',
#  'A4': 'subsidiary_authors',
#  'AB': 'abstract',
#  'AD': 'author_address',
#  'AN': 'accession_number',
#  'AU': 'authors',
#  'C1': 'custom1',
#  'C2': 'custom2',
#  'C3': 'custom3',
#  'C4': 'custom4',
#  'C5': 'custom5',
#  'C6': 'custom6',
#  'C7': 'custom7',
#  'C8': 'custom8',
#  'CA': 'caption',
#  'CN': 'call_number',
#  'CY': 'place_published',
#  'DA': 'date',
#  'DB': 'name_of_database',
#  'DO': 'doi',
#  'DP': 'database_provider',
#  'ET': 'edition',
#  'EP': 'end_page',
#  'ID': 'id',
#  'IS': 'number',
#  'J2': 'alternate_title1',
#  'JA': 'alternate_title2',
#  'JF': 'alternate_title3',
#  'JO': 'journal_name',
#  'KW': 'keywords',
#  'L1': 'file_attachments1',
#  'L2': 'file_attachments2',
#  'L4': 'figure',
#  'LA': 'language',
#  'LB': 'label',
#  'M1': 'note',
#  'M3': 'type_of_work',
#  'N1': 'notes',
#  'N2': 'notes_abstract',
#  'NV': 'number_of_volumes',
#  'OP': 'original_publication',
#  'PB': 'publisher',
#  'PY': 'year',
#  'RI': 'reviewed_item',
#  'RN': 'research_notes',
#  'RP': 'reprint_edition',
#  'SE': 'section',
#  'SN': 'issn',
#  'SP': 'start_page',
#  'ST': 'short_title',
#  'T1': 'primary_title',
#  'T2': 'secondary_title',
#  'T3': 'tertiary_title',
#  'TA': 'translated_author',
#  'TI': 'title',
#  'TT': 'translated_title',
#  'UR': 'urls',
#  'VL': 'volume',
#  'Y1': 'publication_year',
#  'Y2': 'access_date',
#  'ER': 'end_of_reference',
#  'UK': 'unknown_tag',
#  'address': 'place_published'}
